# %% [markdown]
# ## Corpus 구성

# %%
import pandas as pd

df = pd.read_csv("dataset/2024_norm_split.csv")
df.head()
# Out:
#             id                                          title      date  \
# 0  122846231_0  중 군 고위간부 9명 전인대 대표 박탈… '로켓군' 납품 관련 부패사건 연루 의혹  20240101
# 1  122846231_1  중 군 고위간부 9명 전인대 대표 박탈… '로켓군' 납품 관련 부패사건 연루 의혹  20240101
# 2  122846362_0                     서울 12cm 기습 폭설… "이런 눈 또 온다"  20240101
# 3  122846362_1                     서울 12cm 기습 폭설… "이런 눈 또 온다"  20240101
# 4  122846400_0                      '자산 301조원' 머스크, 세계 최고 부자에  20240101
#
#                                              content
# 0  "리상푸 전국방부장 낙마와 연관" 리부장 후임엔 해군출신 둥쥔 중국 당국이 '반(반...
# 1   장비 발전(조달) 부문에 집중됐던 것으로 전해졌다. 커우젠원(구건문) 대만정치대 ...
# 2  13년만에 최대… 도로 곳곳 사고 방파제 추락-조난사고도 발생 "엘니뇨-온난화로 폭...
# 3  역 방향으로 향하는 통일로 5차로에서 추돌사고가 발생해 도로가 한때 부분 통제됐다....
# 4  1년새 124조원 늘어… 증가액도 1위 아르노 LVMH 회장 2위로 밀려나 베이조스...

# %%
corpus = df['content'].tolist()
len(corpus)
# Out:
# 73668

# %%
corpus[:10]
# Out:
# ['"리상푸 전국방부장 낙마와 연관" 리부장 후임엔 해군출신 둥쥔 중국 당국이 \'반(반)부패 표적\'으로 지목된 군 고위 간부 9명의 전국인민대표대회(전국인대) 대의원직을 박탈하면서 강력한 사정 드라이브를 걸고 있다. 중국 당국이 부패 혐의가 제기되온 군 고위급을 잇달아 파면하고 두 달 넘게 공석이던 신임 국방부장을 임명한 것은 군 반부패 드라이브를 지속하는 한편으로 대만과의 긴장 고조, 필리핀 등 남중국해 영유권 분쟁 속 군부의 기강을 잡겠다는 의지의 표명으로 풀이된다. 지난해 12월 31일 중국 관영 신화통신에 따르면 중국 국회 격인 전국인대는 지난해 12월 29일 열린 상무위원회 결과를 발표하면서 "(로켓군 부사령원과 중앙군사위 연합참모부 부참모장인) 장전중(장진중) 등 9명을 전국인대 대표 직무에서 파면한다"고 밝혔다. 이번 전국인대 대표직 박탈은 전략 미사일·항공우주 전력을 담당하는 로켓군과',
#  ' 장비 발전(조달) 부문에 집중됐던 것으로 전해졌다. 커우젠원(구건문) 대만정치대 국제관계연구센터 주임은 "이번에 파면된 전국인대 대표들은 대부분 기술 분야 관리"라며 "중국 중앙군사위가 지난해 7월 시작한 조달 관련 부패·범죄 신고 접수에 따른 것"이라고 설명했다. 중국은 지난해 10월 전격 해임한 리상푸(李상복) 전 국방부장(장관) 후임으로 둥쥔(동군·62·사진) 전 인민해방군 해군 사령원(해군참모총장 격)을 임명했다. 둥 신임 국방부장은 산둥성 옌타이 출신으로 주요 군 경력을 해군에서 쌓은 인물이다. 앞서 리 전 부장 해임도 인민해방군에서 전략 미사일과 항공우주 전력을 담당하는 로켓군을 겨냥한 반부패 조사와 관련된 것으로 알려졌다. 커우 주임은 "리 전 부장 낙마는 이번 인사들의 파면과 관련이 있고, 인민해방군이 큰 사건을 적발했음을 보여준다. 이번 사건이 어디까지 연루될지 현 단계에선 예',
# ...

# %% [markdown]
# ## Custom Kiwi 형태소 분석기로 BM25용 Analyzer 생성

# %%
from kiwipiepy import Kiwi
from kiwipiepy.utils import Stopwords
from typing import List

class Kiwi_Tokenizer:
    def __init__(self, dict_path : str):
        self.kiwi = Kiwi(num_workers=0, model_type='sbg') # SkipBigram(sbg)
        self.stopwords = Stopwords()
        self.kiwi.load_user_dictionary(dict_path=dict_path)

    def __call__(self, sent : str) -> List[str]:
        tokens = self.kiwi.tokenize(sent, stopwords=self.stopwords)
        return [token.form for token in tokens]

# %%
my_tokenizer = Kiwi_Tokenizer("model/custom_dict.txt")

# %%
tokens = my_tokenizer(corpus[0])
print(tokens)
# Out:
# ['리상푸', '전', '국방부장', '낙마', '연관', '리부', '장', '후임', '해군', '출신', '둥쥔', '중국', '당국', '반', '반', '부패', '표적', '지목', '군', '고위', '간부', '9', '명의', '전국인민대표대회', '전국인대', '대', '의원직', '박탈', '강력', '사정', '드라이브', '걸', '중국', '당국', '부패', '혐의', '제기', '오', '군', '고위급', '잇달', '파면', '두', '달', '넘', '공석', '신임', '국방부장', '임명', '군', '반', '부패', '드라이브', '지속', '한편', '대만', '긴장', '고조', '필리핀', '남중국해', '영유', '권', '분쟁', '속', '군부', '기강', '잡', '의지', '표명', '풀이', '지난해', '12', '31', '중국', '관영', '신화통신', '중국', '국회', '격', '전국인대', '지난해', '12', '29', '열리', '상무', '위원회', '결과', '발표', '로켓군', '부사', '령', '원', '중앙군사위', '연합', '참모부', '부', '참모장', '장', '전중', '장', '진중', '9', '전국인대', '대표', '직무', '파면', '밝히', '이번', '전국인대', '대표직', '박탈', '전략', '미사일', '항공', '우주', '전력', '담당', '로켓군']

# %% [markdown]
# ## BM25 모델 생성

# %%
from langchain_milvus.utils.sparse import BM25SparseEmbedding
from pymilvus.model.sparse import BM25EmbeddingFunction

class Custom_BM25(BM25SparseEmbedding):
    def __init__(self, corpus: List[str], tokenizer):
        # super().__init__(corpus=corpus) # fit도 자동으로 하기 때문에 이를 분리하기 위해 __init__은 overriding
        self.corpus = corpus
        self.analyzer = tokenizer # default로 설정된 build_default_analyer가 아닌, 입력된 tokenizer를 analyzer로 설정
        self.bm25_ef = BM25EmbeddingFunction(self.analyzer, num_workers=1)
    
    # corpus에 대해 analyzer를 이용하여 학습하여 BM25 모델을 생성하는 메소드
    def fit(self):
        self.bm25_ef.fit(self.corpus)
    
    # corpus에 대해 fit된 모델을 저장하는 메소드
    def save(self, filename : str):
        self.bm25_ef.save(filename)
    
    # fit된 모델을 로드하는 메소드
    def load(self, filename : str):
        self.bm25_ef.load(filename)
    
    # 그대로 사용하는 메소드
    # embed_query(self, text: str) -> Dict[int, float]
    # embed_documents(self, texts: List[str]) -> List[Dict[int, float]]

# %%
# corpus와 analyzer가 설정된 상태까지
my_BM25 = Custom_BM25(corpus=corpus, tokenizer=my_tokenizer)

# %%
# 선언 당시 저장된 corpus와 analyzer를 기반으로 BM25 모델을 학습
my_BM25.fit() # 총 2시간 소요

# %%
# 학습이 완료된 BM25 모델을 저장
my_BM25.save("model/bm25_model.json")

# %% [markdown]
# ## Sparse Embedding

# %%
# 토크나이저, BM25 모델 로드 등 초기 세팅
tokenizer = Kiwi_Tokenizer("model/custom_dict.txt")
custom_bm25 = Custom_BM25(corpus=[], tokenizer=tokenizer)
custom_bm25.load("model/bm25_model.json")

# %%
import pandas as pd

df = pd.read_csv("dataset/2024_norm_split_ner_pruning.csv")
df.head()
# Out:
#             id                                          title      date  \
# 0  122846231_0  중 군 고위간부 9명 전인대 대표 박탈… '로켓군' 납품 관련 부패사건 연루 의혹  20240101
# 1  122846231_1  중 군 고위간부 9명 전인대 대표 박탈… '로켓군' 납품 관련 부패사건 연루 의혹  20240101
# 2  122846362_0                     서울 12cm 기습 폭설… "이런 눈 또 온다"  20240101
# 3  122846362_1                     서울 12cm 기습 폭설… "이런 눈 또 온다"  20240101
# 4  122846400_0                      '자산 301조원' 머스크, 세계 최고 부자에  20240101
#
#                                              content  \
# 0  "리상푸 전국방부장 낙마와 연관" 리부장 후임엔 해군출신 둥쥔 중국 당국이 '반(반...
# 1   장비 발전(조달) 부문에 집중됐던 것으로 전해졌다. 커우젠원(구건문) 대만정치대 ...
# 2  13년만에 최대… 도로 곳곳 사고 방파제 추락-조난사고도 발생 "엘니뇨-온난화로 폭...
# 3  역 방향으로 향하는 통일로 5차로에서 추돌사고가 발생해 도로가 한때 부분 통제됐다....
# 4  1년새 124조원 늘어… 증가액도 1위 아르노 LVMH 회장 2위로 밀려나 베이조스...
#
#                                                  NER
# 0  리상푸 전국방부장 리부장 해군 둥쥔 중국 군 중국 국방부장 대만 필리핀 남중국해 중...
# 1  커우젠원 구건문 대만정치대 주임 전국인대 중국 중앙군사위 중국 리상푸 李상복 국방부...
# ...

# %%
docs_embedding = custom_bm25.embed_documents(df['content'].tolist()[:10])
for doc_embedding in docs_embedding:
    print(doc_embedding)
# Out:
# {0: 0.962931, 1: 0.962931, 2: 1.3903409, 3: 0.962931, 4: 0.962931, 5: 0.962931, 6: 1.6317686, 7: 0.962931, 8: 0.962931, 9: 0.962931, 10: 0.962931, 11: 1.786914, 12: 1.3903409, 13: 1.6317686, 14: 1.6317686, 15: 0.962931, 16: 0.962931, 17: 1.6317686, 18: 0.962931, 19: 0.962931, 20: 1.3903409, 21: 0.962931, 22: 0.962931, 23: 1.786914, 24: 0.962931, 25: 0.962931, 26: 1.3903409, 27: 0.962931, 28: 0.962931, 29: 1.3903409, 30: 0.962931, 31: 0.962931, 32: 0.962931, 33: 0.962931, 34: 0.962931, 35: 0.962931, 36: 1.3903409, 37: 0.962931, 38: 0.962931, 39: 0.962931, 40: 0.962931, 41: 0.962931, 42: 0.962931, 43: 0.962931, 44: 0.962931, 45: 0.962931, 46: 0.962931, 47: 0.962931, 48: 0.962931, 49: 0.962931, 50: 0.962931, 51: 0.962931, 52: 0.962931, 53: 0.962931, 54: 0.962931, 55: 0.962931, 56: 0.962931, 57: 0.962931, 58: 0.962931, 59: 0.962931, 60: 1.3903409, 61: 1.3903409, 62: 0.962931, 63: 0.962931, 64: 0.962931, 65: 0.962931, 66: 0.962931, 67: 0.962931, 68: 0.962931, 69: 0.962931, 70: 0.962931, 7
# ...
